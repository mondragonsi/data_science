# %% [markdown]
# <a href="https://colab.research.google.com/github/mondragonsi/data_science/blob/main/testing_get_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/sample_data/consulta_cand_2022_PR.csv',delimiter=';',encoding='latin-1')

# %%
data.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  22/10/2022   18:46:14         2022                2  ELEIÇÃO ORDINÁRIA
# 1  22/10/2022   18:46:14         2022                2  ELEIÇÃO ORDINÁRIA
# 2  22/10/2022   18:46:14         2022                2  ELEIÇÃO ORDINÁRIA
# 3  22/10/2022   18:46:14         2022                2  ELEIÇÃO ORDINÁRIA
# 4  22/10/2022   18:46:14         2022                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 0         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 1         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 2         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 3         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 4         1         546  Eleições Gerais Estaduais 2022  02/10/2022
#
#   TP_ABRANGENCIA  ...          NR_PROCESSO CD_SITUACAO_CANDIDATO_PLEITO  \
# ...

# %%
deputados = data[['NM_URNA_CANDIDATO','NM_CANDIDATO','SG_PARTIDO','SG_UF','DS_CARGO','NM_EMAIL','DS_SITUACAO_CANDIDATURA',]]

# %%
deputados
# Out:
#             NM_URNA_CANDIDATO                     NM_CANDIDATO    SG_PARTIDO  \
# 0           LAÉRCIO DE GOUVÊA          LAERCIO GOUVEIA BARBOSA            DC
# 1              NICOLAS IARGAS                   NICOLAS IARGAS          REDE
# 2        TAISA SANTANA - ZACA          TAISA APARECIDA SANTANA           PMN
# 3            EVERSON NATALINO  EVERSON NATALINO LEITE DE LUCIA            PL
# 4             HÉLIO GUIMARÃES           HELIO VIEIRA GUIMARÃES           PSD
# ...                       ...                              ...           ...
# 1578           CRISTINA ARZUA       MARIA CRISTINA NAVIA ARZUA          PODE
# 1579  CABO LUZ DO ACAMPAMENTO           MARCOS DE OLIVEIRA LUZ          PODE
# 1580       ROZANGELA CARTEIRA       ROZANGELA VIDAL DOS SANTOS  REPUBLICANOS
# 1581          CRIS DAS FRUTAS       CRISTIANE GIMENES DA SILVA           PSD
# 1582           HANDREY PETERS            HANDREY GIOVAN PETERS           PDT
#
# ...

# %%
import missingno as msno

# %%
msno.bar(deputados)

# %%
deputados.describe()
# Out:
#         NM_URNA_CANDIDATO                           NM_CANDIDATO SG_PARTIDO  \
# count                1583                                   1583       1583
# unique               1583                                   1581         30
# top     LAÉRCIO DE GOUVÊA  PATRICIA CARRASCHI ALEOTTI MENEGUETTI         PP
# freq                    1                                      2         88
#
#        SG_UF           DS_CARGO        NM_EMAIL DS_SITUACAO_CANDIDATURA
# count   1583               1583            1583                    1583
# unique     1                  7               1                       2
# top       PR  DEPUTADO ESTADUAL  NÃO DIVULGÁVEL                    APTO
# freq    1583                902            1583                    1501

# %%
type(deputados)
# Out:
# pandas.core.frame.DataFrame

# %%
deputados[deputados['SG_PARTIDO']=='PT']
# Out:
#                   NM_URNA_CANDIDATO                            NM_CANDIDATO  \
# 81          ANDRÉ NOGUEIRA DA RÁDIO                 ANDRÉ FONTOURA NOGUEIRA
# 151           AGENTE DALMEY WERLANG                 DALMEY FERNANDO WERLANG
# 191                 ANDREIA DE LIMA                  ANDREIA SOARES DE LIMA
# 198                         MARGOT                     MARGARETE LOPES IUNG
# 201   CÉLIO RODRIGUES MAIS COLETIVO                 CÉLIO LEANDRO RODRIGUES
# ...                             ...                                     ...
# 1442                     ENIO VERRI                         ENIO JOSÉ VERRI
# 1475                 LENIR DE ASSIS                  LENIR CANDIDA DE ASSIS
# 1517                 ANDERSON PREGO              ANDERSON FERREIRA DA SILVA
# 1554  ISABEL DINIZ COLETIVO POPULAR                   ISABEL CRISTINA DINIZ
# 1576                    ZECA DIRCEU  JOSE CARLOS BECKER DE OLIVEIRA E SILVA
#
# ...

# %%
deputados.loc[(deputados['SG_PARTIDO']=='PT') & (deputados['DS_CARGO']=='DEPUTADO FEDERAL')]
# Out:
#                    NM_URNA_CANDIDATO  \
# 81           ANDRÉ NOGUEIRA DA RÁDIO
# 151            AGENTE DALMEY WERLANG
# 201    CÉLIO RODRIGUES MAIS COLETIVO
# 214                        VALENTINA
# 363               ANGELA MARIA DO PT
# 401              HAMILTON SERIGHELLI
# 497      IVAN COLETIVO PODER POPULAR
# 508                           GLEISI
# 531                           WELTER
# 585                     TADEU VENERI
# 662                       CELSO KING
# 676      TERTULIANO RIBAS DE ANDRADE
# 731                    CAROL DARTORA
# 737                           BIANCO
# 825         CRISTIANO FISCAL DO POVO
# 1126  JACQUE DA CASA DAS 13 MULHERES
# 1187                PROF. TEREZINHA
# 1225               ANDERSON TEIXEIRA
# 1301                     NEGÃO DO PT
# 1381                      DR. ADEMIR
# 1440                THAYS BIEBERBACH
# 1442                      ENIO VERRI
# 1475                  LENIR DE ASSIS
# 1517                  ANDERSON PREGO
# ...
